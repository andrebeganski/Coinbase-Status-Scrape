# %%
## importing necessary libraries
from bs4 import BeautifulSoup
import pandas as pd
import requests
from random import randrange ##  allows us to randomize numbers library
import time ## time tracker

# %%
## This link brings us to Coinbase's support page. 
## Before we scrape all 37 pages, we first need to indentify what we are targeting.
url = "https://status.coinbase.com/history?page=1"

# %%
## Pulling down the webpage.
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
## Making some soup.
soup = BeautifulSoup(response.text, "html.parser")

# %%
## Searching for the name of previous incidents, we see they are in a div with data-react-class="HistoryIndex"
## Isolating Incident History div
incident_div = soup.find("div",{'data-react-class': 'HistoryIndex'})

# %%
## selecting "data-react-props"
## tightening range to include just incidents
## replacing curly brackets that break the data up by month, which are not needed
## splitting the string into separate values
s = incident_div["data-react-props"]
start = s.find('"months":[') + 10
end = s.find('}]}]', start)
s = s[start:end].replace("{","").replace("}","")
incident_list = list(s.split(',"'))

# %%
## all this code does is clean the data up and remove values we don't want as data
## some of the date and time values are stored as strangely formatted variables, so we're removing the formatting

clean_incidents = []
for item in incident_list:
     clean_incidents.append(item.replace('"',"")\
                            .replace("\\u003cvar data-var=\'date\'\\u003e","")\
                            .replace("\\u003c/var\\u003e","")\
                            .replace("\\u003cvar data-var=\'time\'\\u003e","")\
                            .replace("\\u003cvar data-var=\'time\'\\u003e","")\
                            .replace("incidents:[","")\
                            .replace("PDT]","PDT")\
                            .replace("PST]","PST"))
## grabbing year
year = "year:"
incident_year = [int(x.replace("year:","")) for x in clean_incidents if year in x]
print(incident_year)
## we will need to add all months in final scrape
## this excludes values that define the month of the incident, year, and the number of days in that month. 
## these variables could be thought of containers for the incidents of a certain month
december = ":December"
january = ":January"
november = ":November"
october = ":October"
september = ":September"
august = ":August"
year = "year:"
starts = "starts_on"
days = "days:"
cleaner_incidents = [ x for x in clean_incidents\
                     if october not in x\
                     and september not in x\
                     and august not in x\
                     and december not in x\
                     and january not in x\
                     and november not in x\
                     and days not in x\
                     and starts not in x\
                     and year not in x]
# Out:
# [2022, 2022, 2022]

# %%
## creating name list
name = "name:"
incident_names = [x.replace("name:","") for x in cleaner_incidents if name in x]

# %%
## creating message list
message = "message:"
incident_messages = [x.replace("message:","") for x in cleaner_incidents if message in x]

# %%
## creating code list
code = "code:"
incident_codes = [x.replace("code:","") for x in cleaner_incidents if code in x]

# %%
## creating impact list
impact = "impact:"
incident_impacts = [x.replace("impact:","") for x in cleaner_incidents if impact in x]

# %%
## creating timestamp list
timestamp = "timestamp:"
incident_timestamps = [x.replace("timestamp:","") for x in cleaner_incidents if timestamp in x]

# %%
## creating year column
## this code is written in a way that gives entries from january the correct year
## there are three months per page. incident_year contains the year for those three months in a list.
## january is always the first month to show up on the page when it's displayed with December and November.
## so, if a timestamp has january in it, we need to assign it the first year value in our list.
incident_years = []
jan = "Jan"
for item in incident_timestamps:
    if jan in item:
        incident_years.append(incident_year[0])
    else:
        incident_years.append(incident_year[2])

# %%
## creating month column
incident_months = []
jan = "Jan"
feb = "Feb"
mar = "Mar"
apr = "Apr"
may = "May"
jun = "Jun"
jul = "Jul"
aug = "Aug"
sep = "Sep"
oct_ = "Oct"
nov = "Nov"
dec = "Dec"
for item in incident_timestamps:
    if jan in item:
        incident_months.append("January")
    elif feb in item:
        incident_months.append("February")
    elif mar in item:
        incident_months.append("March")
    elif apr in item:
        incident_months.append("April")
    elif may in item:
        incident_months.append("May")
    elif jun in item:
        incident_months.append("June")
    elif jul in item:
        incident_months.append("July")
    elif aug in item:
        incident_months.append("August")
    elif sep in item:
        incident_months.append("September")
    elif oct_ in item:
        incident_months.append("October")
    elif nov in item:
        incident_months.append("November")
    elif dec in item:
        incident_months.append("December")
    else:
        incident_months.append("None")

# %%
## compling data into df

incident_dict = []
for (name,impact,timestamp,message,code,year,month) in zip(incident_names,incident_impacts,incident_timestamps,incident_messages,incident_codes,incident_years,incident_months):
    incident_dict.append({
        "Name":name,
        "Impact":impact,
        "Timestamp":timestamp,
        "Message":message,
        "Code":code,
        "Year":year,
        "Month":month
    })
df = pd.DataFrame.from_dict(incident_dict)
df
# Out:
#                                                  Name       Impact  \
# 0   Order cancellations and order executions may b...         none
# 1              Outage for PayID payments in Australia     critical
# 2   We're currently experiencing degraded performa...         none
# 3            HBAR deposit address generation disabled  maintenance
# 4     [Scheduled] Scheduled Maintenance: Coinbase.com  maintenance
# ..                                                ...          ...
# 62  Coinbase Pay sends for BCH, ETC, AVAX unavailable        major
# 63    [Scheduled] Scheduled Maintenance: Coinbase.com  maintenance
# 64                         Advanced Trade RARE Delays         none
# 65                        Elevated Order Entry Errors        minor
# 66         Successful upgrade for Kyber Network (KNC)        minor
#
#                             Timestamp  \
# 0   Oct 14, 07:47 - Oct 17, 07:49 PDT
# 1   Oct 13, 21:05 - Oct 14, 01:47 PDT
# 2           Oct 13, 11:43 - 15:54 PDT
# 3           Oct 12, 12:19 - 18:24 PDT
# 4           Oct 12, 13:01 - 14:00 PDT
# ..                                ...
# 62           Aug 2, 13:26 - 14:37 PDT
# 63           Aug 2, 13:00 - 14:00 PDT
# 64           Aug 2, 10:29 - 10:42 PDT
# 65   Jul 27, 12:45 - Aug 2, 10:32 PDT
# 66   Jul 27, 09:13 - Aug 2, 09:02 PDT
#
#                                               Message          Code  Year  \
# 0                    This incident has been resolved.  sf51lgl4lwlm  2022
# 1                    This incident has been resolved.  dy8mlp6wq4t6  2022
# 2                    This incident has been resolved.  93705zkdr4lf  2022
# 3                    This incident has been resolved.  f41j926st8d9  2022
# 4       The scheduled maintenance has been completed.  kvhcxpbvx01k  2022
# ..                                                ...           ...   ...
# 62                   This incident has been resolved.  c19pn5pm8h5c  2022
# 63      The scheduled maintenance has been completed.  7p3rfn60hdph  2022
# 64                   This incident has been resolved.  hm05n4rk2ytc  2022
# 65                   This incident has been resolved.  37x8txryt05y  2022
# 66  We have successfully implemented an upgrade on...  s72v8yxccnz6  2022
#
#       Month
# 0   October
# 1   October
# 2   October
# 3   October
# 4   October
# ..      ...
# 62   August
# 63   August
# 64   August
# 65     July
# 66     July
#
# [67 rows x 7 columns]

# %%
##Now lets make a function that does all of that for us!
def compileIncidents(response):
    soup = BeautifulSoup(response.text, "html.parser")
    incident_div = soup.find("div",{'data-react-class': 'HistoryIndex'})
    s = incident_div["data-react-props"]
    start = s.find('"months":[') + 10
    end = s.find('}]}]', start)
    s = s[start:end].replace("{","").replace("}","")
    incident_list = list(s.split(',"'))
    clean_incidents = []
    for item in incident_list:
         clean_incidents.append(item.replace('"',"")\
                            .replace("\\u003cvar data-var=\'date\'\\u003e","")\
                            .replace("\\u003c/var\\u003e","")\
                            .replace("\\u003cvar data-var=\'time\'\\u003e","")\
                            .replace("\\u003cvar data-var=\'time\'\\u003e","")\
                            .replace("incidents:[","")\
                            .replace("PDT]","PDT")\
                            .replace("PST]","PST"))
    year = "year:"
    incident_year = [int(x.replace("year:","")) for x in clean_incidents if year in x]
    january = ":January"
    febraury = ":February"
    march = ":March"
    april = ":April"
    may = ":May"
    june = ":June"
    july = ":July"
    august = ":August"
    september = ":September"
    october = ":October"
    november = ":November"
    december = ":December"
    august = ":August"
    year = "year:"
    starts = "starts_on"
    days = "days:"
    cleaner_incidents = [ x for x in clean_incidents\
                     if january not in x\
                     and febraury not in x\
                     and march not in x\
                     and april not in x\
                     and may not in x\
                     and june not in x\
                     and july not in x\
                     and august not in x\
                     and september not in x\
                     and october not in x\
                     and november not in x\
                     and december not in x\
                     and days not in x\
                     and starts not in x\
                     and year not in x]
    name = "name:"
    incident_names = [x.replace("name:","") for x in cleaner_incidents if name in x]
    message = "message:"
    incident_messages = [x.replace("message:","") for x in cleaner_incidents if message in x]
    code = "code:"
    incident_codes = [x.replace("code:","") for x in cleaner_incidents if code in x]
    impact = "impact:"
    incident_impacts = [x.replace("impact:","") for x in cleaner_incidents if impact in x]
    timestamp = "timestamp:"
    incident_timestamps = [x.replace("timestamp:","") for x in cleaner_incidents if timestamp in x]
    incident_years = []
    jan = "Jan"
    for item in incident_timestamps:
        if jan in item:
            incident_years.append(incident_year[0])
        else:
            incident_years.append(incident_year[2])
    incident_months = []
    jan = "Jan"
    feb = "Feb"
    mar = "Mar"
    apr = "Apr"
    may_ = "May"
    jun = "Jun"
    jul = "Jul"
    aug = "Aug"
    sep = "Sep"
    oct_ = "Oct"
    nov = "Nov"
    dec = "Dec"
    for item in incident_timestamps:
        if jan in item:
            incident_months.append("January")
        elif feb in item:
            incident_months.append("February")
        elif mar in item:
            incident_months.append("March")
        elif apr in item:
            incident_months.append("April")
        elif may_ in item:
            incident_months.append("May")
        elif jun in item:
            incident_months.append("June")
        elif jul in item:
            incident_months.append("July")
        elif aug in item:
            incident_months.append("August")
        elif sep in item:
            incident_months.append("September")
        elif oct_ in item:
            incident_months.append("October")
        elif nov in item:
            incident_months.append("November")
        elif dec in item:
            incident_months.append("December")
        else:
            incident_months.append("None")
    incident_dict = []
    for (name,impact,timestamp,message,code,year,month) in zip(incident_names,incident_impacts,incident_timestamps,incident_messages,incident_codes,incident_years,incident_months):
        incident_dict.append({
            "Name":name,
            "Impact":impact,
            "Timestamp":timestamp,
            "Message":message,
            "Code":code,
            "Year":year,
            "Month":month
        })
    df = pd.DataFrame.from_dict(incident_dict)
    return df

# %%
##creating function to generate links
base_url = "https://status.coinbase.com/history?page="
def generateLinks(base_url,total_pages):
    '''
    Provide the base url with number of pages to generate links
    '''
    links = []
    for number in range(1, total_pages + 1): 
        links.append(f"{base_url}{number}") 
    return links

# %%
##creating snoozer
def sleepyTime():
    snoozer = randrange(30,60)
    print(f"snoozing for {snoozer} second before next scrape")
    time.sleep(snoozer)

# %%
##creating list processor
def processList(all_dfs, file_name):
    df = pd.concat(all_dfs, ignore_index = True)
    df.to_csv(file_name, encoding = "UTF-8", index = False)
    print(f"{file_name} is in you current folder")
    return df

# %%
##creating scraper function
def myScraper(url,total_pages,file_name):
    '''
    Input: List links you would like to scrape, total pages, and file name.
    Output: Final df, list of broken links.
    '''
    my_links = generateLinks(url,total_pages)
    all_dfs = []
    busted_links = []

    counter = 1
    for link in my_links:
        print(f"scraping {counter} of {len(my_links)}")
        counter += 1
        print(f"scraping {link}")
        response = requests.get(link)
        if response.status_code == 200:
            df = compileIncidents(response)
            all_dfs.append(df)
        else:
            print(f"{link} returned a posted link with response {response.status_code}")
            busted_links.append(link)
        if counter < len(my_links):
            sleepyTime()
        else:
            pass
    final_df = processList(all_dfs,file_name)
    print("all done!")
    return (final_df,busted_links)

# %%
url = "https://status.coinbase.com/history?page="
total_pages = 37
file_name = "Coinbase-Incidents.csv"
test_df = myScraper(url,total_pages,file_name)[0]
test_df
# Out:
# scraping 1 of 37
# scraping https://status.coinbase.com/history?page=1
# snoozing for 31 second before next scrape
# scraping 2 of 37
# scraping https://status.coinbase.com/history?page=2
# snoozing for 50 second before next scrape
# scraping 3 of 37
# scraping https://status.coinbase.com/history?page=3
# snoozing for 34 second before next scrape
# scraping 4 of 37
# scraping https://status.coinbase.com/history?page=4
# snoozing for 58 second before next scrape
# scraping 5 of 37
# scraping https://status.coinbase.com/history?page=5
# snoozing for 57 second before next scrape
# scraping 6 of 37
# scraping https://status.coinbase.com/history?page=6
# snoozing for 42 second before next scrape
# scraping 7 of 37
# scraping https://status.coinbase.com/history?page=7
# snoozing for 57 second before next scrape
# scraping 8 of 37
# scraping https://status.coinbase.com/history?page=8
# snoozing for 43 second before next scrape
# scraping 9 of 37
# scraping https://status.coinbase.com/history?page=9
# snoozing for 53 second before next scrape
# scraping 10 of 37
# scraping https://status.coinbase.com/history?page=10
# snoozing for 41 second before next scrape
# scraping 11 of 37
# scraping https://status.coinbase.com/history?page=11
# snoozing for 38 second before next scrape
# scraping 12 of 37
# scraping https://status.coinbase.com/history?page=12
# snoozing for 39 second before next scrape
# scraping 13 of 37
# scraping https://status.coinbase.com/history?page=13
# snoozing for 39 second before next scrape
# scraping 14 of 37
# scraping https://status.coinbase.com/history?page=14
# snoozing for 45 second before next scrape
# scraping 15 of 37
# scraping https://status.coinbase.com/history?page=15
# snoozing for 47 second before next scrape
# scraping 16 of 37
# scraping https://status.coinbase.com/history?page=16
# snoozing for 35 second before next scrape
# scraping 17 of 37
# scraping https://status.coinbase.com/history?page=17
# snoozing for 42 second before next scrape
# scraping 18 of 37
# scraping https://status.coinbase.com/history?page=18
# snoozing for 56 second before next scrape
# scraping 19 of 37
# scraping https://status.coinbase.com/history?page=19
# snoozing for 36 second before next scrape
# scraping 20 of 37
# scraping https://status.coinbase.com/history?page=20
# snoozing for 44 second before next scrape
# scraping 21 of 37
# scraping https://status.coinbase.com/history?page=21
# snoozing for 53 second before next scrape
# scraping 22 of 37
# scraping https://status.coinbase.com/history?page=22
# snoozing for 47 second before next scrape
# scraping 23 of 37
# scraping https://status.coinbase.com/history?page=23
# snoozing for 47 second before next scrape
# scraping 24 of 37
# scraping https://status.coinbase.com/history?page=24
# snoozing for 46 second before next scrape
# scraping 25 of 37
# scraping https://status.coinbase.com/history?page=25
# snoozing for 33 second before next scrape
# scraping 26 of 37
# scraping https://status.coinbase.com/history?page=26
# snoozing for 47 second before next scrape
# scraping 27 of 37
# scraping https://status.coinbase.com/history?page=27
# snoozing for 52 second before next scrape
# scraping 28 of 37
# scraping https://status.coinbase.com/history?page=28
# snoozing for 45 second before next scrape
# scraping 29 of 37
# scraping https://status.coinbase.com/history?page=29
# snoozing for 50 second before next scrape
# scraping 30 of 37
# scraping https://status.coinbase.com/history?page=30
# snoozing for 41 second before next scrape
# scraping 31 of 37
# scraping https://status.coinbase.com/history?page=31
# snoozing for 39 second before next scrape
# scraping 32 of 37
# scraping https://status.coinbase.com/history?page=32
# snoozing for 41 second before next scrape
# scraping 33 of 37
# scraping https://status.coinbase.com/history?page=33
# snoozing for 34 second before next scrape
# scraping 34 of 37
# scraping https://status.coinbase.com/history?page=34
# snoozing for 32 second before next scrape
# scraping 35 of 37
# scraping https://status.coinbase.com/history?page=35
# snoozing for 54 second before next scrape
# scraping 36 of 37
# scraping https://status.coinbase.com/history?page=36
# scraping 37 of 37
# scraping https://status.coinbase.com/history?page=37
# Coinbase-Incidents.csv is in you current folder
# all done!
#                                                Name       Impact  \
# 0                       Hedera send/receive delayed         none
# 1    Delayed Cardano (ADA) deposits and withdrawals        minor
# 2            Outage for PayID payments in Australia     critical
# 3        [Scheduled] Optimism scheduled maintenance  maintenance
# 4          Delayed Bitcoin (BTC) Sends and Receives         none
# ..                                              ...          ...
# 910                               Pending transfers         none
# 911                  Login issues on some browsers.         none
# 912                                          Outage         none
# 913                                          Outage        minor
# 914                            Degraded performance        minor
#
#                              Timestamp  \
# 0                    Oct 12, 10:13 PDT
# 1    Oct 11, 11:23 - Oct 12, 06:59 PDT
# 2                    Oct 12, 02:35 PDT
# 3            Oct 11, 11:00 - 11:30 PDT
# 4             Oct 9, 20:50 - 22:58 PDT
# ..                                 ...
# 910  Dec 24, 14:37 - Dec 25, 07:20 PST
# 911          Dec 20, 16:24 - 16:31 PST
# 912          Dec 10, 20:06 - 20:06 PST
# 913           Dec 6, 16:40 - 18:09 PST
# 914          Sep 29, 21:58 - 22:16 PDT
#
#                                                Message          Code  Year  \
# 0           We are currently investigating this issue.  j5bs06khzm2x  2022
# 1                     This incident has been resolved.  jnd10j7lqff8  2022
# 2    We're aware of an issue with our 3rd-party pay...  k92hmdlrldb2  2022
# 3        The scheduled maintenance has been completed.  r820kxfvtbc5  2022
# 4                     This incident has been resolved.  hwl4m7f0cs92  2022
# ..                                                 ...           ...   ...
# 910                   This incident has been resolved.  xm70l90z4j6r  2013
# 911                   This incident has been resolved.  t2r1xq9lzyt6  2013
# 912  Apologies for the downtime - service has been ...  rp11hz18xb28  2013
# 913                   This incident has been resolved.  wvls2y6scbry  2013
# 914                       We're back.  All systems go.  3k5rwskw382c  2013
#
#          Month
# 0      October
# 1      October
# 2      October
# 3      October
# 4      October
# ..         ...
# 910   December
# 911   December
# 912   December
# 913   December
# 914  September
#
# [915 rows x 7 columns]

# %%
test_df[test_df["Impact"] == "critical"]
# Out:
#                                                   Name    Impact  \
# 2               Outage for PayID payments in Australia  critical
# 57    Coinbase.com is experiencing connectivity issues  critical
# 102   Coinbase.com is experiencing connectivity issues  critical
# 209                  iDEAL and Sofort payments delayed  critical
# 239    Sofort and iDEAL Payments Currently Unavailable  critical
# 266                         Coinbase Card Swipe issues  critical
# 267   Coinbase.com is experiencing connectivity issues  critical
# 414  Card purchases, card withdrawals, and PayPal p...  critical
# 417                        SEPA Payment Service Outage  critical
# 433                    Ethereum Berlin Network Upgrade  critical
# 479  We are currently investigating issues with car...  critical
# 499       SEPA EUR Withdrawals Temporarily Unavailable  critical
# 500                       Coinbase Help Center is Down  critical
# 528   Coinbase.com is experiencing connectivity issues  critical
# 537   Coinbase.com is experiencing connectivity issues  critical
# 540                Website and mobile apps not loading  critical
# 545            Paypal EUR \u0026 GBP Withdrawal Outage  critical
# 586   Coinbase.com is experiencing connectivity issues  critical
# 589   Coinbase.com is experiencing connectivity issues  critical
# 627   Coinbase.com is experiencing connectivity issues  critical
# 641                         Issues with card purchases  critical
# 654  Unable to process credit and debit card transa...  critical
# 655   Temporarily unable to process Paypal withdrawals  critical
# 664               Degraded performance on Coinbase.com  critical
# 666                                  Coinbase.com down  critical
# 671  EOS Sends and Receives are temporarily unavail...  critical
# 672  Stellar Sends and Receives are temporarily una...  critical
#
#                              Timestamp  \
# 2                    Oct 12, 02:35 PDT
# 57            Aug 3, 13:31 - 14:34 PDT
# 102          Jun 21, 00:09 - 01:30 PDT
# 209          Jan 11, 09:34 - 15:36 PST
# 239           Dec 7, 09:08 - 15:24 PST
# 266          Oct 27, 12:38 - 14:31 PDT
# 267          Oct 27, 07:18 - 11:13 PDT
# 414           Jun 3, 12:32 - 13:35 PDT
# 417           Jun 1, 16:35 - 18:38 PDT
# 433          Apr 15, 04:50 - 15:27 PDT
# 479          Feb 22, 04:53 - 05:38 PST
# 499  Jan 27, 11:03 - Jan 28, 11:18 PST
# 500          Jan 27, 13:33 - 14:27 PST
# 528           Dec 9, 16:48 - 17:30 PST
# 537          Nov 26, 06:14 - 09:02 PST
# 540          Nov 16, 12:45 - 14:27 PST
# 545  Nov 10, 08:12 - Nov 11, 08:11 PST
# 586           Jun 1, 16:14 - 16:58 PDT
# 589          Apr 29, 10:38 - 14:02 PDT
# 627          Jan 24, 06:59 - 07:32 PST
# 641          Nov 20, 14:19 - 16:25 PST
# 654           Sep 2, 08:12 - 11:34 PDT
# 655          Aug 17, 06:15 - 09:44 PDT
# 664          Jun 26, 13:47 - 14:38 PDT
# 666          Jun 24, 05:28 - 06:39 PDT
# 671          Jun 12, 05:34 - 07:31 PDT
# 672          Jun 10, 09:26 - 11:47 PDT
#
#                                                Message          Code  Year  \
# 2    We're aware of an issue with our 3rd-party pay...  k92hmdlrldb2  2022
# 57                    This incident has been resolved.  h5y9db55bwcq  2022
# 102                   This incident has been resolved.  mj0ysm01x2nc  2022
# 209                   This incident has been resolved.  rvmx7h9p4jqq  2022
# 239                   This incident has been resolved.  01dwynn34xl0  2021
# 266                   This incident has been resolved.  fjtngsrsgx88  2021
# 267                   This incident has been resolved.  v5dx8y2mtqx2  2021
# 414                   This incident has been resolved.  9l6j38p5mfs1  2021
# 417                   This incident has been resolved.  0t5ln2lzhrdk  2021
# 433                   This incident has been resolved.  w4fmfqypt630  2021
# 479                   This incident has been resolved.  qnyw0zbqcw0n  2021
# 499                   This incident has been resolved.  rsjx6xlxc15y  2021
# 500                   This incident has been resolved.  d3l8p694wmxc  2021
# 528                   This incident has been resolved.  fx6gtrzyp4hj  2020
# 537  We've resolved the issue. All systems are oper...  yjq3bch7zgt1  2020
# 540                   This incident has been resolved.  85j21s852sv2  2020
# 545                   This incident has been resolved.  g5zgjlgqt0m6  2020
# 586                   This incident has been resolved.  nyh33mmw2c6f  2020
# 589                   This incident has been resolved.  0yjzscppm4sb  2020
# 627                   This incident has been resolved.  n6rtqlr2syy4  2020
# 641                   This incident has been resolved.  0z5v1j19jms8  2019
# 654                   This incident has been resolved.  0812pv3pvdmy  2019
# 655                   This incident has been resolved.  nvzjq3dhbqbc  2019
# 664                   This incident has been resolved.  jw25lkc5r2x4  2019
# 666                   This incident has been resolved.  szjlfcc0zk32  2019
# 671                   This incident has been resolved.  vww6fjlwl81n  2019
# 672  The underlying issue has been addressed. Sends...  4m6ry2pzvd70  2019
#
#          Month
# 2      October
# 57      August
# 102       June
# 209    January
# 239   December
# 266    October
# 267    October
# 414       June
# 417       June
# 433      April
# 479   February
# 499    January
# 500    January
# 528   December
# 537   November
# 540   November
# 545   November
# 586       June
# 589      April
# 627    January
# 641   November
# 654  September
# 655     August
# 664       June
# 666       June
# 671       June
# 672       June

# %%
test_df[test_df["Impact"] == "major"]
# Out:
#                                                   Name Impact  \
# 8         ACH withdrawals, deposits, and buys failures  major
# 42                          International USDC Trading  major
# 58   Coinbase Pay sends for BCH, ETC, AVAX unavailable  major
# 92    Coinbase.com is experiencing connectivity issues  major
# 94   Coinbase Pay crypto sends are failing at high ...  major
# ..                                                 ...    ...
# 879       We're experiencing a high number of requests  major
# 886                          Coinbase Exchange Offline  major
# 890                                     Website outage  major
# 891                        Network Connectivity Issues  major
# 892                                    Exchange outage  major
#
#                              Timestamp  \
# 8             Oct 2, 03:57 - 09:41 PDT
# 42   Jul 19, 09:08 - Aug 23, 07:06 PDT
# 58            Aug 2, 13:26 - 14:37 PDT
# 92           Jun 27, 14:27 - 20:47 PDT
# 94   Jun 26, 09:58 - Jun 27, 10:20 PDT
# ..                                 ...
# 879          Dec 23, 11:36 - 11:41 PST
# 886           Sep 2, 16:41 - 16:55 PDT
# 890          Jul 13, 04:22 - 05:25 PDT
# 891           Jul 6, 14:22 - 14:54 PDT
# 892           Jul 2, 12:43 - 15:17 PDT
#
#                                                Message          Code  Year  \
# 8                     This incident has been resolved.  b45vlknj3cml  2022
# 42                    This incident has been resolved.  j49qg8j0h8hp  2022
# 58                    This incident has been resolved.  c19pn5pm8h5c  2022
# 92                    This incident has been resolved.  7bh5w0jqf4h3  2022
# 94                    This incident has been resolved.  k94rnj3nvkqh  2022
# ..                                                 ...           ...   ...
# 879                   This incident has been resolved.  6ppglr77hl8c  2015
# 886                               Exchange is back up.  p8t93bjt6cvv  2015
# 890                   This incident has been resolved.  jqw9bv00vf2q  2015
# 891  We have mitigated issues caused by our upstrea...  mwyzfbr3mvjb  2015
# 892                   Exchange is up and 100% healthy.  5jy2xx659y6r  2015
#
#          Month
# 8      October
# 42        July
# 58      August
# 92        June
# 94        June
# ..         ...
# 879   December
# 886  September
# 890       July
# 891       July
# 892       July
#
# [144 rows x 7 columns]

# %%
test_df[test_df["Name"] == "Coinbase.com is experiencing connectivity issues"]
# Out:
#                                                  Name    Impact  \
# 57   Coinbase.com is experiencing connectivity issues  critical
# 92   Coinbase.com is experiencing connectivity issues     major
# 101  Coinbase.com is experiencing connectivity issues     major
# 102  Coinbase.com is experiencing connectivity issues  critical
# 130  Coinbase.com is experiencing connectivity issues     minor
# 248  Coinbase.com is experiencing connectivity issues     major
# 265  Coinbase.com is experiencing connectivity issues     major
# 267  Coinbase.com is experiencing connectivity issues  critical
# 511  Coinbase.com is experiencing connectivity issues     minor
# 525  Coinbase.com is experiencing connectivity issues      none
# 528  Coinbase.com is experiencing connectivity issues  critical
# 537  Coinbase.com is experiencing connectivity issues  critical
# 544  Coinbase.com is experiencing connectivity issues     minor
# 570  Coinbase.com is experiencing connectivity issues     minor
# 575  Coinbase.com is experiencing connectivity issues     major
# 586  Coinbase.com is experiencing connectivity issues  critical
# 589  Coinbase.com is experiencing connectivity issues  critical
# 606  Coinbase.com is experiencing connectivity issues     major
# 608  Coinbase.com is experiencing connectivity issues     major
# 627  Coinbase.com is experiencing connectivity issues  critical
# 630  Coinbase.com is experiencing connectivity issues     major
# 634  Coinbase.com is experiencing connectivity issues     minor
#
#                              Timestamp  \
# 57            Aug 3, 13:31 - 14:34 PDT
# 92           Jun 27, 14:27 - 20:47 PDT
# 101          Jun 23, 11:08 - 11:50 PDT
# 102          Jun 21, 00:09 - 01:30 PDT
# 130          Apr 25, 01:13 - 01:51 PDT
# 248          Nov 23, 16:21 - 17:56 PST
# 265          Oct 27, 12:40 - 14:54 PDT
# 267          Oct 27, 07:18 - 11:13 PDT
# 511           Jan 7, 07:50 - 22:13 PST
# 525          Dec 16, 06:45 - 08:27 PST
# 528           Dec 9, 16:48 - 17:30 PST
# 537          Nov 26, 06:14 - 09:02 PST
# 544          Nov 11, 10:55 - 13:24 PST
# 570          Jul 28, 02:19 - 04:21 PDT
# 575          Jul 17, 14:23 - 15:58 PDT
# 586           Jun 1, 16:14 - 16:58 PDT
# 589          Apr 29, 10:38 - 14:02 PDT
# 606          Feb 20, 14:22 - 15:27 PST
# 608          Feb 19, 14:15 - 14:52 PST
# 627          Jan 24, 06:59 - 07:32 PST
# 630  Jan 14, 11:06 - Jan 15, 08:03 PST
# 634          Dec 17, 14:22 - 14:35 PST
#
#                                                Message          Code  Year  \
# 57                    This incident has been resolved.  h5y9db55bwcq  2022
# 92                    This incident has been resolved.  7bh5w0jqf4h3  2022
# 101                   This incident has been resolved.  wzv8ht040xyn  2022
# 102                   This incident has been resolved.  mj0ysm01x2nc  2022
# 130                   This incident has been resolved.  c6h0mn0262hq  2022
# 248                   This incident has been resolved.  zsz65cz5clzy  2021
# 265                   This incident has been resolved.  5tv5swyq8jg3  2021
# 267                   This incident has been resolved.  v5dx8y2mtqx2  2021
# 511                   This incident has been resolved.  3yd0mclly9b4  2021
# 525                   This incident has been resolved.  93smh99lxtxz  2020
# 528                   This incident has been resolved.  fx6gtrzyp4hj  2020
# 537  We've resolved the issue. All systems are oper...  yjq3bch7zgt1  2020
# 544                   This incident has been resolved.  ky01hsfqzqsj  2020
# 570                   This incident has been resolved.  tgz6d7ffcq1p  2020
# 575                   This incident has been resolved.  1twmtrlfmm8j  2020
# 586                   This incident has been resolved.  nyh33mmw2c6f  2020
# 589                   This incident has been resolved.  0yjzscppm4sb  2020
# 606                   This incident has been resolved.  7tt4ghtzhgk5  2020
# 608                   This incident has been resolved.  87pfyybysh00  2020
# 627                   This incident has been resolved.  n6rtqlr2syy4  2020
# 630                   This incident has been resolved.  vllgz002xv39  2020
# 634                   This incident has been resolved.  vvfx5fhm4p6p  2019
#
#         Month
# 57     August
# 92       June
# 101      June
# 102      June
# 130     April
# 248  November
# 265   October
# 267   October
# 511   January
# 525  December
# 528  December
# 537  November
# 544  November
# 570      July
# 575      July
# 586      June
# 589     April
# 606  February
# 608  February
# 627   January
# 630   January
# 634  December
